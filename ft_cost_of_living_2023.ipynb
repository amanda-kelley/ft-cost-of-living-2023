# %% [markdown]
# <a href="https://colab.research.google.com/github/amanda-kelley/ft-cost-of-living-2023/blob/main/ft_cost_of_living_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2023&region=021'
cost_of_living = pd.read_html(url)

# %%
cost_of_living

# %%
cost2023 = cost_of_living[1]
cost2023
# Out:
#     Rank                              City  Cost of Living Index  Rent Index  \
# 0    NaN                 Hamilton, Bermuda                 142.1        96.1
# 1    NaN  Santa Barbara, CA, United States                 112.2        92.9
# 2    NaN       Honolulu, HI, United States                 102.7        61.6
# 3    NaN       New York, NY, United States                 100.0       100.0
# 4    NaN  San Francisco, CA, United States                  99.6        92.4
# ..   ...                               ...                   ...         ...
# 85   NaN                  Kingston, Canada                  63.7        35.1
# 86   NaN                  Brampton, Canada                  63.5        35.1
# 87   NaN                    Regina, Canada                  62.0        21.7
# 88   NaN                   Windsor, Canada                  61.3        29.7
# 89   NaN      Knoxville, TN, United States                  60.7        33.9
#
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2022&region=021'
cost_of_living2 = pd.read_html(url)

# %%
cost_of_living2
# Out:
# [    0                                                  1
#  0 NaN  whenDocReady(function() {  jQuery('#city_selec...,
#       Rank                              City  Cost of Living Index  Rent Index  \
#  0     NaN                 Hamilton, Bermuda                 149.0        96.1
#  1     NaN       Honolulu, HI, United States                 103.6        65.1
#  2     NaN       New York, NY, United States                 100.0       100.0
#  3     NaN  Santa Barbara, CA, United States                  95.0        78.4
#  4     NaN       Berkeley, CA, United States                  94.4        88.2
#  ..    ...                               ...                   ...         ...
#  119   NaN        Memphis, TN, United States                  62.3        34.9
#  120   NaN          Akron, OH, United States                  62.2        22.9
#  121   NaN    Little Rock, AR, United States                  59.3        25.6
# ...

# %%
cost2022 = cost_of_living2[1]
cost2022
# Out:
#      Rank                              City  Cost of Living Index  Rent Index  \
# 0     NaN                 Hamilton, Bermuda                 149.0        96.1
# 1     NaN       Honolulu, HI, United States                 103.6        65.1
# 2     NaN       New York, NY, United States                 100.0       100.0
# 3     NaN  Santa Barbara, CA, United States                  95.0        78.4
# 4     NaN       Berkeley, CA, United States                  94.4        88.2
# ..    ...                               ...                   ...         ...
# 119   NaN        Memphis, TN, United States                  62.3        34.9
# 120   NaN          Akron, OH, United States                  62.2        22.9
# 121   NaN    Little Rock, AR, United States                  59.3        25.6
# 122   NaN        Wichita, KS, United States                  58.9        24.3
# 123   NaN        El Paso, TX, United States                  55.9        23.2
#
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2021&region=021'
cost_of_living3 = pd.read_html(url)

# %%
cost_of_living3
# Out:
# [    0                                                  1
#  0 NaN  whenDocReady(function() {  jQuery('#city_selec...,
#       Rank                              City  Cost of Living Index  Rent Index  \
#  0     NaN                 Hamilton, Bermuda                 146.3        89.1
#  1     NaN       New York, NY, United States                 100.0       100.0
#  2     NaN       Honolulu, HI, United States                  95.9        65.6
#  3     NaN  San Francisco, CA, United States                  93.3       109.3
#  4     NaN      Anchorage, AK, United States                  92.2        37.6
#  ..    ...                               ...                   ...         ...
#  117   NaN    Little Rock, AR, United States                  62.9        25.8
#  118   NaN        Memphis, TN, United States                  62.7        29.4
#  119   NaN        Wichita, KS, United States                  61.1        23.9
# ...

# %%
cost2021 = cost_of_living3[1]
cost2021
# Out:
#      Rank                              City  Cost of Living Index  Rent Index  \
# 0     NaN                 Hamilton, Bermuda                 146.3        89.1
# 1     NaN       New York, NY, United States                 100.0       100.0
# 2     NaN       Honolulu, HI, United States                  95.9        65.6
# 3     NaN  San Francisco, CA, United States                  93.3       109.3
# 4     NaN      Anchorage, AK, United States                  92.2        37.6
# ..    ...                               ...                   ...         ...
# 117   NaN    Little Rock, AR, United States                  62.9        25.8
# 118   NaN        Memphis, TN, United States                  62.7        29.4
# 119   NaN        Wichita, KS, United States                  61.1        23.9
# 120   NaN      Lexington, KY, United States                  60.2        26.9
# 121   NaN        El Paso, TX, United States                  54.5        22.6
#
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2020&region=021'
cost_of_living4 = pd.read_html(url)

# %%
cost2020 = cost_of_living4[1]
cost2020
# Out:
#     Rank                              City  Cost of Living Index  Rent Index  \
# 0    NaN       New York, NY, United States                 100.0       100.0
# 1    NaN  San Francisco, CA, United States                  91.5       115.6
# 2    NaN      Anchorage, AK, United States                  91.4        38.9
# 3    NaN       Honolulu, HI, United States                  89.7        63.0
# 4    NaN       Brooklyn, NY, United States                  88.8        80.5
# ..   ...                               ...                   ...         ...
# 70   NaN     Cincinnati, OH, United States                  61.6        34.0
# 71   NaN          Boise, ID, United States                  60.7        34.5
# 72   NaN                    London, Canada                  60.0        26.6
# 73   NaN    Little Rock, AR, United States                  59.8        26.4
# 74   NaN        El Paso, TX, United States                  52.4        22.7
#
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2019&region=021'
cost_of_living5 = pd.read_html(url)

# %%
cost2019 = cost_of_living5[1]
cost2019
# Out:
#     Rank                              City  Cost of Living Index  Rent Index  \
# 0    NaN       New York, NY, United States                 100.0       100.0
# 1    NaN       Honolulu, HI, United States                  95.7        61.6
# 2    NaN     Washington, DC, United States                  92.0        70.5
# 3    NaN  San Francisco, CA, United States                  91.7       106.1
# 4    NaN       Brooklyn, NY, United States                  90.3        80.0
# ..   ...                               ...                   ...         ...
# 74   NaN        Detroit, MI, United States                  60.0        33.8
# 75   NaN                  Hamilton, Canada                  59.7        25.1
# 76   NaN                 Kitchener, Canada                  58.9        26.0
# 77   NaN          Boise, ID, United States                  58.9        30.4
# 78   NaN                    London, Canada                  57.1        22.6
#
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2018&region=021'
cost_of_living6 = pd.read_html(url)

# %%
cost2018 = cost_of_living6[1]
cost2018
# Out:
#      Rank                                City  Cost of Living Index  \
# 0     NaN                   Hamilton, Bermuda                 145.4
# 1     NaN         New York, NY, United States                 100.0
# 2     NaN    San Francisco, CA, United States                  97.8
# 3     NaN        Anchorage, AK, United States                  95.0
# 4     NaN         Honolulu, HI, United States                  94.1
# ..    ...                                 ...                   ...
# 157   NaN            Boise, ID, United States                  62.6
# 158   NaN        Knoxville, TN, United States                  62.2
# 159   NaN  College Station, TX, United States                  61.8
# 160   NaN      San Antonio, TX, United States                  60.9
# 161   NaN           Athens, GA, United States                  60.5
#
#      Rent Index  Cost of Living Plus Rent Index  Groceries Index  \
# 0         110.9                           128.8            143.5
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2017&region=021'
cost_of_living7 = pd.read_html(url)

# %%
cost2017 = cost_of_living7[1]
cost2017
# Out:
#      Rank                              City  Cost of Living Index  Rent Index  \
# 0     NaN                 Hamilton, Bermuda                 141.8       113.4
# 1     NaN       New York, NY, United States                 100.0       100.0
# 2     NaN       Honolulu, HI, United States                  99.5        67.3
# 3     NaN  San Francisco, CA, United States                  99.1       125.8
# 4     NaN      Anchorage, AK, United States                  98.7        44.5
# ..    ...                               ...                   ...         ...
# 133   NaN           Reno, NV, United States                  61.9        31.0
# 134   NaN                 Kitchener, Canada                  61.8        25.1
# 135   NaN         Athens, GA, United States                  61.7        24.6
# 136   NaN    Springfield, MO, United States                  61.5        18.9
# 137   NaN                  Hamilton, Canada                  61.5        24.4
#
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2016&region=021'
cost_of_living8 = pd.read_html(url)

# %%
cost2016 = cost_of_living8[1]
cost2016
# Out:
#      Rank                              City  Cost of Living Index  Rent Index  \
# 0     NaN                 Hamilton, Bermuda                 132.3       120.9
# 1     NaN  San Francisco, CA, United States                 103.4       121.6
# 2     NaN       New York, NY, United States                 100.0       100.0
# 3     NaN       Honolulu, HI, United States                  99.7        64.5
# 4     NaN     Washington, DC, United States                  96.2        72.2
# ..    ...                               ...                   ...         ...
# 114   NaN                  Montreal, Canada                  61.7        22.3
# 115   NaN                 Kitchener, Canada                  60.0        23.2
# 116   NaN                   Moncton, Canada                  59.6        17.3
# 117   NaN           Reno, NV, United States                  57.1        25.8
# 118   NaN                  Hamilton, Canada                  56.0        19.8
#
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2015&region=021'
cost_of_living9 = pd.read_html(url)

# %%
cost2015 = cost_of_living9[1]
cost2015
# Out:
#     Rank                               City  Cost of Living Index  Rent Index  \
# 0    NaN                  Hamilton, Bermuda                 163.6       120.0
# 1    NaN              Fort McMurray, Canada                 109.5        71.0
# 2    NaN        Honolulu, HI, United States                 104.2        64.9
# 3    NaN        New York, NY, United States                 100.0       100.0
# 4    NaN       Anchorage, AK, United States                  99.8        40.0
# ..   ...                                ...                   ...         ...
# 89   NaN   Oklahoma City, OK, United States                  69.7        22.6
# 90   NaN  Salt Lake City, UT, United States                  69.7        31.1
# 91   NaN     Los Angeles, CA, United States                  69.4        57.7
# 92   NaN           Boise, ID, United States                  68.9        24.5
# 93   NaN           Omaha, NE, United States                  63.4        23.8
#
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2014&region=021'
cost_of_living10 = pd.read_html(url)

# %%
cost2014 = cost_of_living10[1]
cost2014
# Out:
#     Rank                           City  Cost of Living Index  Rent Index  \
# 0    NaN    Honolulu, HI, United States                 106.3        69.6
# 1    NaN  Washington, DC, United States                 100.4        71.5
# 2    NaN    New York, NY, United States                 100.0       100.0
# 3    NaN                 Barrie, Canada                  99.7        29.3
# 4    NaN                Halifax, Canada                  99.3        39.1
# ..   ...                            ...                   ...         ...
# 84   NaN       Tulsa, OK, United States                  69.9        32.0
# 85   NaN       Omaha, NE, United States                  69.5        29.1
# 86   NaN  Fort Worth, TX, United States                  69.3        29.7
# 87   NaN       Boise, ID, United States                  68.3        25.0
# 88   NaN   Milwaukee, WI, United States                  67.8        29.9
#
#     Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/region_rankings.jsp?title=2013&region=021'
cost_of_living11 = pd.read_html(url)

# %%
cost2013 = cost_of_living11[1]
cost2013
# Out:
#     Rank                            City  Cost of Living Index  Rent Index  \
# 0    NaN                 Calgary, Canada                 110.1        44.9
# 1    NaN                  Regina, Canada                 108.3        40.5
# 2    NaN               Vancouver, Canada                 107.7        58.0
# 3    NaN   Washington, DC, United States                 105.6        78.5
# 4    NaN                Edmonton, Canada                 105.2        46.6
# ..   ...                             ...                   ...         ...
# 61   NaN      Atlanta, GA, United States                  77.8        40.3
# 62   NaN  Albuquerque, NM, United States                  76.6        27.2
# 63   NaN    Rochester, NY, United States                  75.7        33.6
# 64   NaN   Des Moines, IA, United States                  75.0        27.6
# 65   NaN    Milwaukee, WI, United States                  74.8        29.3
#
# ...
