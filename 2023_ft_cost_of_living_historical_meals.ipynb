# %% [markdown]
# <a href="https://colab.research.google.com/github/amanda-kelley/ft-cost-of-living-2023/blob/main/2023_ft_cost_of_living_historical_meals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2013&itemId=114&itemId=6&itemId=3&itemId=2'
historical_meal = pd.read_html(url)

meal2013 = historical_meal[2]
meal2013
# Out:
#      Rank                      City  \
# 0     NaN  Saint Petersburg, Russia
# 1     NaN          Algiers, Algeria
# 2     NaN           Florence, Italy
# 3     NaN              Genoa, Italy
# 4     NaN              Milan, Italy
# ..    ...                       ...
# 336   NaN             Gent, Belgium
# 337   NaN         Sydney, Australia
# 338   NaN            Bologna, Italy
# 339   NaN         Alexandria, Egypt
# 340   NaN            Quito, Ecuador
#
#     Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                47.02
# 1                                                28.55
# 2                                                77.92
# 3                                                74.68
# 4                                                90.91
# ..                                                 ...
# 336                                              71.43
# 337                                              76.92
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2014&itemId=114&itemId=6&itemId=3&itemId=2'
historical_meal2 = pd.read_html(url)

meal2014 = historical_meal2[2]
meal2014
# Out:
#      Rank                                City  \
# 0     NaN            Saint Petersburg, Russia
# 1     NaN                      Samara, Russia
# 2     NaN                    Algiers, Algeria
# 3     NaN  Banja Luka, Bosnia And Herzegovina
# 4     NaN                 Guadalajara, Mexico
# ..    ...                                 ...
# 400   NaN                    Antwerp, Belgium
# 401   NaN                       Lviv, Ukraine
# 402   NaN                 Novosibirsk, Russia
# 403   NaN                   Brussels, Belgium
# 404   NaN                       Gent, Belgium
#
#     Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                42.95
# 1                                                57.27
# 2                                                25.26
# 3                                                27.76
# 4                                                23.31
# ..                                                 ...
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2015&itemId=114&itemId=6&itemId=3&itemId=2'
historical_meal3 = pd.read_html(url)

meal2015 = historical_meal3[2]
meal2015
# Out:
#      Rank                       City  \
# 0     NaN            Leuven, Belgium
# 1     NaN   Saint Petersburg, Russia
# 2     NaN             Samara, Russia
# 3     NaN           Algiers, Algeria
# 4     NaN  Eugene, OR, United States
# ..    ...                        ...
# 537   NaN              Lviv, Ukraine
# 538   NaN        Novosibirsk, Russia
# 539   NaN          Brussels, Belgium
# 540   NaN              Gent, Belgium
# 541   NaN     Rostov-na-donu, Russia
#
#     Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                    -
# 1                                                37.42
# 2                                                    -
# 3                                                25.11
# 4                                                40.00
# ..                                                 ...
# 537                                              14.25
# 538                                              26.20
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2016&itemId=114&itemId=6&itemId=3&itemId=2'
historical_meal4 = pd.read_html(url)

meal2016 = historical_meal4[2]
meal2016
# Out:
#      Rank                      City  \
# 0     NaN           Leuven, Belgium
# 1     NaN  Saint Petersburg, Russia
# 2     NaN     Yogyakarta, Indonesia
# 3     NaN            Samara, Russia
# 4     NaN          Algiers, Algeria
# ..    ...                       ...
# 603   NaN       Novosibirsk, Russia
# 604   NaN         Brussels, Belgium
# 605   NaN             Gent, Belgium
# 606   NaN       Surabaya, Indonesia
# 607   NaN    Rostov-na-donu, Russia
#
#     Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                79.46
# 1                                                30.74
# 2                                                 7.57
# 3                                                27.67
# 4                                                22.78
# ..                                                 ...
# 603                                              18.44
# 604                                              68.11
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2017&itemId=114&itemId=6&itemId=3&itemId=2'
historical_meal5 = pd.read_html(url)

meal2017 = historical_meal5[2]
meal2017
# Out:
#      Rank                      City  \
# 0     NaN           Leuven, Belgium
# 1     NaN    Dumaguete, Philippines
# 2     NaN  Saint Petersburg, Russia
# 3     NaN     Yogyakarta, Indonesia
# 4     NaN         Chihuahua, Mexico
# ..    ...                       ...
# 640   NaN          Medan, Indonesia
# 641   NaN         Brussels, Belgium
# 642   NaN             Gent, Belgium
# 643   NaN       Surabaya, Indonesia
# 644   NaN    Rostov-na-donu, Russia
#
#     Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                67.17
# 1                                                12.12
# 2                                                35.07
# 3                                                 4.52
# 4                                                    -
# ..                                                 ...
# 640                                                  -
# 641                                              69.97
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2018&itemId=114&itemId=6&itemId=3&itemId=2'
historical_meal6 = pd.read_html(url)

meal2018 = historical_meal6[2]
meal2018
# Out:
#      Rank                      City  \
# 0     NaN           Leuven, Belgium
# 1     NaN    Dumaguete, Philippines
# 2     NaN  Saint Petersburg, Russia
# 3     NaN     Yogyakarta, Indonesia
# 4     NaN         Chihuahua, Mexico
# ..    ...                       ...
# 723   NaN              Omsk, Russia
# 724   NaN             Gent, Belgium
# 725   NaN    Aguascalientes, Mexico
# 726   NaN       Surabaya, Indonesia
# 727   NaN    Rostov-na-donu, Russia
#
#     Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                    -
# 1                                                    -
# 2                                                32.05
# 3                                                 5.76
# 4                                                    -
# ..                                                 ...
# 723                                                  -
# 724                                              70.07
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2019&itemId=114&itemId=6&itemId=3&itemId=2'
historical_meal7 = pd.read_html(url)

meal2019 = historical_meal7[2]
meal2019
# Out:
#      Rank                      City  \
# 0     NaN           Leuven, Belgium
# 1     NaN    Dumaguete, Philippines
# 2     NaN  Saint Petersburg, Russia
# 3     NaN     Yogyakarta, Indonesia
# 4     NaN         Chihuahua, Mexico
# ..    ...                       ...
# 731   NaN              Omsk, Russia
# 732   NaN             Gent, Belgium
# 733   NaN    Aguascalientes, Mexico
# 734   NaN       Surabaya, Indonesia
# 735   NaN    Rostov-na-donu, Russia
#
#     Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                    -
# 1                                                    -
# 2                                                30.55
# 3                                                10.47
# 4                                                19.12
# ..                                                 ...
# 731                                                  -
# 732                                              67.16
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2020&itemId=114&itemId=6&itemId=3&itemId=2'
historical_meal8 = pd.read_html(url)

meal2020 = historical_meal8[2]
meal2020
# Out:
#      Rank                      City  \
# 0     NaN           Leuven, Belgium
# 1     NaN  Saint Petersburg, Russia
# 2     NaN            Samara, Russia
# 3     NaN          Algiers, Algeria
# 4     NaN           Saratov, Russia
# ..    ...                       ...
# 678   NaN         Brussels, Belgium
# 679   NaN              Omsk, Russia
# 680   NaN             Gent, Belgium
# 681   NaN       Surabaya, Indonesia
# 682   NaN    Rostov-na-donu, Russia
#
#     Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                    -
# 1                                                28.51
# 2                                                    -
# 3                                                25.30
# 4                                                    -
# ..                                                 ...
# 678                                              66.80
# 679                                                  -
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2021&itemId=114&itemId=6&itemId=3&itemId=2'
historical_meal9 = pd.read_html(url)

meal2021 = historical_meal9[2]
meal2021
# Out:
#      Rank                      City  \
# 0     NaN           Leuven, Belgium
# 1     NaN  Saint Petersburg, Russia
# 2     NaN            Samara, Russia
# 3     NaN          Algiers, Algeria
# 4     NaN           Saratov, Russia
# ..    ...                       ...
# 635   NaN       Novosibirsk, Russia
# 636   NaN         Brussels, Belgium
# 637   NaN              Omsk, Russia
# 638   NaN             Gent, Belgium
# 639   NaN    Rostov-na-donu, Russia
#
#     Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                    -
# 1                                                34.10
# 2                                                    -
# 3                                                22.52
# 4                                                    -
# ..                                                 ...
# 635                                              27.28
# 636                                              73.33
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2022&itemId=114&itemId=6&itemId=3&itemId=2'
historical_meal10 =pd.read_html(url)

meal2022 = historical_meal10[2]
meal2022
# Out:
#      Rank                      City  \
# 0     NaN           Leuven, Belgium
# 1     NaN  Saint Petersburg, Russia
# 2     NaN         Chihuahua, Mexico
# 3     NaN            Samara, Russia
# 4     NaN          Algiers, Algeria
# ..    ...                       ...
# 761   NaN         Brussels, Belgium
# 762   NaN              Omsk, Russia
# 763   NaN             Gent, Belgium
# 764   NaN       Surabaya, Indonesia
# 765   NaN    Rostov-na-donu, Russia
#
#     Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                72.47
# 1                                                48.37
# 2                                                    -
# 3                                                48.37
# 4                                                20.68
# ..                                                 ...
# 761                                              74.60
# 762                                                  -
# ...
