# %% [markdown]
# <a href="https://colab.research.google.com/github/amanda-kelley/ft-cost-of-living-2023/blob/main/2023_ft_cost_of_living_historical_groceries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2022&itemId=110&itemId=118&itemId=121&itemId=19&itemId=11&itemId=113&itemId=9&itemId=12&itemId=8&itemId=119&itemId=111&itemId=112&itemId=115&itemId=116&itemId=13'
historical_food = pd.read_html(url)

# %%
food2022 = historical_food[2]
food2022
# Out:
#      Rank                      City Milk (regular), (1 liter)  \
# 0     NaN           Leuven, Belgium                      1.07
# 1     NaN  Saint Petersburg, Russia                      1.30
# 2     NaN         Chihuahua, Mexico                         -
# 3     NaN            Samara, Russia                      1.25
# 4     NaN          Algiers, Algeria                      0.83
# ..    ...                       ...                       ...
# 761   NaN         Brussels, Belgium                      1.27
# 762   NaN              Omsk, Russia                      1.04
# 763   NaN             Gent, Belgium                      1.06
# 764   NaN       Surabaya, Indonesia                      1.20
# 765   NaN    Rostov-na-donu, Russia                      1.22
#
#     Loaf of Fresh White Bread (500g) Eggs (regular) (12) Local Cheese (1kg)  \
# 0                               1.52                2.24                  -
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2021&itemId=110&itemId=118&itemId=121&itemId=19&itemId=11&itemId=113&itemId=9&itemId=12&itemId=8&itemId=119&itemId=111&itemId=112&itemId=115&itemId=116&itemId=13'
historical_food2 = pd.read_html(url)

# %%
food2021 = historical_food2[2]
food2021
# Out:
#      Rank                      City Milk (regular), (1 liter)  \
# 0     NaN           Leuven, Belgium                      1.06
# 1     NaN  Saint Petersburg, Russia                      0.94
# 2     NaN            Samara, Russia                      0.93
# 3     NaN          Algiers, Algeria                      0.73
# 4     NaN           Saratov, Russia                      0.76
# ..    ...                       ...                       ...
# 635   NaN       Novosibirsk, Russia                      0.90
# 636   NaN         Brussels, Belgium                      1.20
# 637   NaN              Omsk, Russia                      0.78
# 638   NaN             Gent, Belgium                      1.07
# 639   NaN    Rostov-na-donu, Russia                      0.92
#
#     Loaf of Fresh White Bread (500g) Eggs (regular) (12) Local Cheese (1kg)  \
# 0                               2.00                2.98                  -
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2020&itemId=110&itemId=118&itemId=121&itemId=19&itemId=11&itemId=113&itemId=9&itemId=12&itemId=8&itemId=119&itemId=111&itemId=112&itemId=115&itemId=116&itemId=13'
historical_food3 = pd.read_html(url)

# %%
food2020 = historical_food3[2]
food2020
# Out:
#      Rank                      City Milk (regular), (1 liter)  \
# 0     NaN           Leuven, Belgium                         -
# 1     NaN  Saint Petersburg, Russia                      0.92
# 2     NaN            Samara, Russia                      0.94
# 3     NaN          Algiers, Algeria                      0.71
# 4     NaN           Saratov, Russia                      0.86
# ..    ...                       ...                       ...
# 678   NaN         Brussels, Belgium                      1.19
# 679   NaN              Omsk, Russia                      0.79
# 680   NaN             Gent, Belgium                      0.86
# 681   NaN       Surabaya, Indonesia                      1.31
# 682   NaN    Rostov-na-donu, Russia                      0.92
#
#     Loaf of Fresh White Bread (500g) Eggs (regular) (12) Local Cheese (1kg)  \
# 0                                  -                2.58                  -
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2019&itemId=110&itemId=118&itemId=121&itemId=19&itemId=11&itemId=113&itemId=9&itemId=12&itemId=8&itemId=119&itemId=111&itemId=112&itemId=115&itemId=116&itemId=13'
historical_food4 = pd.read_html(url)

# %%
food2019 = historical_food4[2]
food2019
# Out:
#      Rank                      City Milk (regular), (1 liter)  \
# 0     NaN           Leuven, Belgium                         -
# 1     NaN    Dumaguete, Philippines                         -
# 2     NaN  Saint Petersburg, Russia                      1.06
# 3     NaN     Yogyakarta, Indonesia                         -
# 4     NaN         Chihuahua, Mexico                      1.00
# ..    ...                       ...                       ...
# 731   NaN              Omsk, Russia                         -
# 732   NaN             Gent, Belgium                      1.10
# 733   NaN    Aguascalientes, Mexico                         -
# 734   NaN       Surabaya, Indonesia                      1.19
# 735   NaN    Rostov-na-donu, Russia                      0.96
#
#     Loaf of Fresh White Bread (500g) Eggs (regular) (12) Local Cheese (1kg)  \
# 0                                  -                   -                  -
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2018&itemId=110&itemId=118&itemId=121&itemId=19&itemId=11&itemId=113&itemId=9&itemId=12&itemId=8&itemId=119&itemId=111&itemId=112&itemId=115&itemId=116&itemId=13'
historical_food5 = pd.read_html(url)

# %%
food2018 = historical_food5[2]
food2018
# Out:
#      Rank                      City Milk (regular), (1 liter)  \
# 0     NaN           Leuven, Belgium                         -
# 1     NaN    Dumaguete, Philippines                      1.42
# 2     NaN  Saint Petersburg, Russia                      1.01
# 3     NaN     Yogyakarta, Indonesia                         -
# 4     NaN         Chihuahua, Mexico                         -
# ..    ...                       ...                       ...
# 723   NaN              Omsk, Russia                         -
# 724   NaN             Gent, Belgium                      1.10
# 725   NaN    Aguascalientes, Mexico                         -
# 726   NaN       Surabaya, Indonesia                         -
# 727   NaN    Rostov-na-donu, Russia                         -
#
#     Loaf of Fresh White Bread (500g) Eggs (regular) (12) Local Cheese (1kg)  \
# 0                                  -                   -                  -
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2017&itemId=110&itemId=118&itemId=121&itemId=19&itemId=11&itemId=113&itemId=9&itemId=12&itemId=8&itemId=119&itemId=111&itemId=112&itemId=115&itemId=116&itemId=13'
historical_food6 = pd.read_html(url)

# %%
food2017 = historical_food6[2]
food2017
# Out:
#      Rank                      City Milk (regular), (1 liter)  \
# 0     NaN           Leuven, Belgium                      0.91
# 1     NaN    Dumaguete, Philippines                      1.45
# 2     NaN  Saint Petersburg, Russia                      1.06
# 3     NaN     Yogyakarta, Indonesia                         -
# 4     NaN         Chihuahua, Mexico                         -
# ..    ...                       ...                       ...
# 640   NaN          Medan, Indonesia                         -
# 641   NaN         Brussels, Belgium                      1.19
# 642   NaN             Gent, Belgium                         -
# 643   NaN       Surabaya, Indonesia                         -
# 644   NaN    Rostov-na-donu, Russia                      1.00
#
#     Loaf of Fresh White Bread (500g) Eggs (regular) (12) Local Cheese (1kg)  \
# 0                               1.96                   -                  -
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2016&itemId=110&itemId=118&itemId=121&itemId=19&itemId=11&itemId=113&itemId=9&itemId=12&itemId=8&itemId=119&itemId=111&itemId=112&itemId=115&itemId=116&itemId=13'
historical_food7 = pd.read_html(url)

# %%
food2016 = historical_food7[2]
food2016
# Out:
#      Rank                      City Milk (regular), (1 liter)  \
# 0     NaN           Leuven, Belgium                         -
# 1     NaN  Saint Petersburg, Russia                      0.89
# 2     NaN     Yogyakarta, Indonesia                         -
# 3     NaN            Samara, Russia                      0.79
# 4     NaN          Algiers, Algeria                      0.35
# ..    ...                       ...                       ...
# 603   NaN       Novosibirsk, Russia                      0.83
# 604   NaN         Brussels, Belgium                      1.12
# 605   NaN             Gent, Belgium                         -
# 606   NaN       Surabaya, Indonesia                      1.23
# 607   NaN    Rostov-na-donu, Russia                      0.81
#
#     Loaf of Fresh White Bread (500g) Eggs (regular) (12) Local Cheese (1kg)  \
# 0                                  -                   -                  -
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2015&itemId=110&itemId=118&itemId=121&itemId=19&itemId=11&itemId=113&itemId=9&itemId=12&itemId=8&itemId=119&itemId=111&itemId=112&itemId=115&itemId=116&itemId=13'
historical_food8 = pd.read_html(url)

# %%
food2015 = historical_food8[2]
food2015
# Out:
#      Rank                       City Milk (regular), (1 liter)  \
# 0     NaN            Leuven, Belgium                         -
# 1     NaN   Saint Petersburg, Russia                      1.04
# 2     NaN             Samara, Russia                         -
# 3     NaN           Algiers, Algeria                      0.30
# 4     NaN  Eugene, OR, United States                      0.69
# ..    ...                        ...                       ...
# 537   NaN              Lviv, Ukraine                      0.60
# 538   NaN        Novosibirsk, Russia                      1.00
# 539   NaN          Brussels, Belgium                      1.16
# 540   NaN              Gent, Belgium                         -
# 541   NaN     Rostov-na-donu, Russia                      0.87
#
#     Loaf of Fresh White Bread (500g) Eggs (regular) (12) Local Cheese (1kg)  \
# 0                                  -                   -                  -
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2014&itemId=110&itemId=118&itemId=121&itemId=19&itemId=11&itemId=113&itemId=9&itemId=12&itemId=8&itemId=119&itemId=111&itemId=112&itemId=115&itemId=116&itemId=13'
historical_food9 = pd.read_html(url)

# %%
food2014 = historical_food9[2]
food2014
# Out:
#      Rank                                City Milk (regular), (1 liter)  \
# 0     NaN            Saint Petersburg, Russia                      1.34
# 1     NaN                      Samara, Russia                      1.24
# 2     NaN                    Algiers, Algeria                      0.44
# 3     NaN  Banja Luka, Bosnia And Herzegovina                      0.93
# 4     NaN                 Guadalajara, Mexico                      1.08
# ..    ...                                 ...                       ...
# 400   NaN                    Antwerp, Belgium                      1.24
# 401   NaN                       Lviv, Ukraine                      0.82
# 402   NaN                 Novosibirsk, Russia                      1.35
# 403   NaN                   Brussels, Belgium                      1.45
# 404   NaN                       Gent, Belgium                         -
#
#     Loaf of Fresh White Bread (500g) Eggs (regular) (12) Local Cheese (1kg)  \
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2013&itemId=110&itemId=118&itemId=121&itemId=19&itemId=11&itemId=113&itemId=9&itemId=12&itemId=8&itemId=119&itemId=111&itemId=112&itemId=115&itemId=116&itemId=13'
historical_food10 = pd.read_html(url)

# %%
food2013 = historical_food10[2]
food2013
# Out:
#      Rank                      City Milk (regular), (1 liter)  \
# 0     NaN  Saint Petersburg, Russia                      1.22
# 1     NaN          Algiers, Algeria                      0.55
# 2     NaN           Florence, Italy                      1.51
# 3     NaN              Genoa, Italy                      1.96
# 4     NaN              Milan, Italy                      1.78
# ..    ...                       ...                       ...
# 336   NaN             Gent, Belgium                         -
# 337   NaN         Sydney, Australia                      1.54
# 338   NaN            Bologna, Italy                      1.47
# 339   NaN         Alexandria, Egypt                      1.10
# 340   NaN            Quito, Ecuador                      1.13
#
#     Loaf of Fresh White Bread (500g) Eggs (regular) (12) Local Cheese (1kg)  \
# 0                               0.99                1.72               9.13
# ...
