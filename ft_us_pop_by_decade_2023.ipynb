# %% [markdown]
# <a href="https://colab.research.google.com/github/amanda-kelley/ft-cost-of-living-2023/blob/main/ft_us_pop_by_decade_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_most_populous_cities_in_the_United_States_by_decade#'
wiki_pop = pd.read_html(url)

# %%
cities2020 = wiki_pop[24]
cities2020
# Out:
#    Rank          City         State  Population[27]  \
# 0     1      New York      New York         8804190
# 1     2   Los Angeles    California         3898747
# 2     3       Chicago      Illinois         2746388
# 3     4       Houston         Texas         2304580
# 4     5       Phoenix       Arizona         1608139
# 5     6  Philadelphia  Pennsylvania         1603797
# 6     7   San Antonio         Texas         1434625
# 7     8     San Diego    California         1386932
# 8     9        Dallas         Texas         1304379
# 9    10      San Jose    California         1013240
#
#                                                Notes
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Phoenix passes Philadelphia to become the firs...
# 5  For the first time, Philadelphia drops out of ...
# ...

# %%
cities2010 = wiki_pop[23]
cities2010
# Out:
#    Rank          City         State  Population[3]  \
# 0     1      New York      New York        8175133
# 1     2   Los Angeles    California        3792621
# 2     3       Chicago      Illinois        2695598
# 3     4       Houston         Texas        2099451
# 4     5  Philadelphia  Pennsylvania        1526006
# 5     6       Phoenix       Arizona        1445632
# 6     7   San Antonio         Texas        1327407
# 7     8     San Diego    California        1307402
# 8     9        Dallas         Texas        1197816
# 9    10      San Jose    California         945942
#
#                                                Notes
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  First city in the South or Texas to surpass 2 ...
# 4                  First population gain since 1950.
# 5  Phoenix briefly experienced population decline...
# ...
