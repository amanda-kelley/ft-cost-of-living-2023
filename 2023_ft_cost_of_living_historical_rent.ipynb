# %% [markdown]
# <a href="https://colab.research.google.com/github/amanda-kelley/ft-cost-of-living-2023/blob/main/2023_ft_cost_of_living_historical_rent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2022&itemId=27&itemId=26&itemId=29&itemId=28&itemId=30&itemId=33&itemId=34'
historical_rent = pd.read_html(url)

# %%
historical_rent
# Out:
# [    0                                                  1
#  0 NaN  whenDocReady(function() {  jQuery('#city_selec...,
#                                                     0
#  0  This page allows you to see historical prices ...,
#       Rank                      City Apartment (1 bedroom) in City Centre  \
#  0     NaN           Leuven, Belgium                               864.48
#  1     NaN  Saint Petersburg, Russia                               706.48
#  2     NaN         Chihuahua, Mexico                                    -
#  3     NaN            Samara, Russia                               364.38
#  4     NaN          Algiers, Algeria                               250.23
#  ..    ...                       ...                                  ...
#  761   NaN         Brussels, Belgium                              1005.58
#  762   NaN              Omsk, Russia                               327.82
#  763   NaN             Gent, Belgium                               979.15
# ...

# %%
rent2022 = historical_rent[2]
rent2022
# Out:
#      Rank                      City Apartment (1 bedroom) in City Centre  \
# 0     NaN           Leuven, Belgium                               864.48
# 1     NaN  Saint Petersburg, Russia                               706.48
# 2     NaN         Chihuahua, Mexico                                    -
# 3     NaN            Samara, Russia                               364.38
# 4     NaN          Algiers, Algeria                               250.23
# ..    ...                       ...                                  ...
# 761   NaN         Brussels, Belgium                              1005.58
# 762   NaN              Omsk, Russia                               327.82
# 763   NaN             Gent, Belgium                               979.15
# 764   NaN       Surabaya, Indonesia                               293.01
# 765   NaN    Rostov-na-donu, Russia                               443.37
#
#     Apartment (1 bedroom) Outside of Centre  \
# 0                                    752.68
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2021&itemId=27&itemId=26&itemId=29&itemId=28&itemId=30&itemId=33&itemId=34'
historical_rent2 = pd.read_html(url)

# %%
historical_rent2
# Out:
# [    0                                                  1
#  0 NaN  whenDocReady(function() {  jQuery('#city_selec...,
#                                                     0
#  0  This page allows you to see historical prices ...,
#       Rank                      City Apartment (1 bedroom) in City Centre  \
#  0     NaN           Leuven, Belgium                               926.46
#  1     NaN  Saint Petersburg, Russia                               585.77
#  2     NaN            Samara, Russia                                    -
#  3     NaN          Algiers, Algeria                               221.53
#  4     NaN           Saratov, Russia                                    -
#  ..    ...                       ...                                  ...
#  635   NaN       Novosibirsk, Russia                               336.99
#  636   NaN         Brussels, Belgium                              1113.35
#  637   NaN              Omsk, Russia                                    -
# ...

# %%
rent2021 = historical_rent2[2]
rent2021
# Out:
#      Rank                      City Apartment (1 bedroom) in City Centre  \
# 0     NaN           Leuven, Belgium                               926.46
# 1     NaN  Saint Petersburg, Russia                               585.77
# 2     NaN            Samara, Russia                                    -
# 3     NaN          Algiers, Algeria                               221.53
# 4     NaN           Saratov, Russia                                    -
# ..    ...                       ...                                  ...
# 635   NaN       Novosibirsk, Russia                               336.99
# 636   NaN         Brussels, Belgium                              1113.35
# 637   NaN              Omsk, Russia                                    -
# 638   NaN             Gent, Belgium                               970.92
# 639   NaN    Rostov-na-donu, Russia                               272.78
#
#     Apartment (1 bedroom) Outside of Centre  \
# 0                                    831.12
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2020&itemId=27&itemId=26&itemId=29&itemId=28&itemId=30&itemId=33&itemId=34'
historical_rent3 = pd.read_html(url)

# %%
rent2020 = historical_rent3[2]
rent2020
# Out:
#      Rank                      City Apartment (1 bedroom) in City Centre  \
# 0     NaN           Leuven, Belgium                               870.66
# 1     NaN  Saint Petersburg, Russia                               536.47
# 2     NaN            Samara, Russia                               285.10
# 3     NaN          Algiers, Algeria                               265.55
# 4     NaN           Saratov, Russia                               232.83
# ..    ...                       ...                                  ...
# 678   NaN         Brussels, Belgium                               946.36
# 679   NaN              Omsk, Russia                                    -
# 680   NaN             Gent, Belgium                               839.20
# 681   NaN       Surabaya, Indonesia                                    -
# 682   NaN    Rostov-na-donu, Russia                               350.26
#
#     Apartment (1 bedroom) Outside of Centre  \
# 0                                    808.31
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2019&itemId=27&itemId=26&itemId=29&itemId=28&itemId=30&itemId=33&itemId=34'
historical_rent4 = pd.read_html(url)

# %%
rent2019 = historical_rent4[2]
rent2019
# Out:
#      Rank                      City Apartment (1 bedroom) in City Centre  \
# 0     NaN           Leuven, Belgium                               755.56
# 1     NaN    Dumaguete, Philippines                               341.96
# 2     NaN  Saint Petersburg, Russia                               551.21
# 3     NaN     Yogyakarta, Indonesia                                    -
# 4     NaN         Chihuahua, Mexico                                    -
# ..    ...                       ...                                  ...
# 731   NaN              Omsk, Russia                                    -
# 732   NaN             Gent, Belgium                               835.59
# 733   NaN    Aguascalientes, Mexico                                    -
# 734   NaN       Surabaya, Indonesia                               286.28
# 735   NaN    Rostov-na-donu, Russia                               294.80
#
#     Apartment (1 bedroom) Outside of Centre  \
# 0                                    658.55
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2018&itemId=27&itemId=26&itemId=29&itemId=28&itemId=30&itemId=33&itemId=34'
historical_rent5 = pd.read_html(url)

# %%
rent2018 = historical_rent5[2]
rent2018
# Out:
#      Rank                      City Apartment (1 bedroom) in City Centre  \
# 0     NaN           Leuven, Belgium                               817.47
# 1     NaN    Dumaguete, Philippines                               273.55
# 2     NaN  Saint Petersburg, Russia                               557.36
# 3     NaN     Yogyakarta, Indonesia                                    -
# 4     NaN         Chihuahua, Mexico                                    -
# ..    ...                       ...                                  ...
# 723   NaN              Omsk, Russia                               246.77
# 724   NaN             Gent, Belgium                               817.96
# 725   NaN    Aguascalientes, Mexico                               143.39
# 726   NaN       Surabaya, Indonesia                                    -
# 727   NaN    Rostov-na-donu, Russia                               308.01
#
#     Apartment (1 bedroom) Outside of Centre  \
# 0                                    719.37
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2017&itemId=27&itemId=26&itemId=29&itemId=28&itemId=30&itemId=33&itemId=34'
historical_rent6 = pd.read_html(url)

# %%
rent2017 = historical_rent6[2]
rent2017
# Out:
#      Rank                      City Apartment (1 bedroom) in City Centre  \
# 0     NaN           Leuven, Belgium                               794.89
# 1     NaN    Dumaguete, Philippines                               276.06
# 2     NaN  Saint Petersburg, Russia                               614.75
# 3     NaN     Yogyakarta, Indonesia                                    -
# 4     NaN         Chihuahua, Mexico                                    -
# ..    ...                       ...                                  ...
# 640   NaN          Medan, Indonesia                                    -
# 641   NaN         Brussels, Belgium                               872.89
# 642   NaN             Gent, Belgium                               790.70
# 643   NaN       Surabaya, Indonesia                               278.52
# 644   NaN    Rostov-na-donu, Russia                               326.14
#
#     Apartment (1 bedroom) Outside of Centre  \
# 0                                    660.55
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2016&itemId=27&itemId=26&itemId=29&itemId=28&itemId=30&itemId=33&itemId=34'
historical_rent7 = pd.read_html(url)

# %%
rent2016 = historical_rent7[2]
rent2016
# Out:
#      Rank                      City Apartment (1 bedroom) in City Centre  \
# 0     NaN           Leuven, Belgium                               771.94
# 1     NaN  Saint Petersburg, Russia                               518.04
# 2     NaN     Yogyakarta, Indonesia                                    -
# 3     NaN            Samara, Russia                               335.58
# 4     NaN          Algiers, Algeria                               255.90
# ..    ...                       ...                                  ...
# 603   NaN       Novosibirsk, Russia                               334.16
# 604   NaN         Brussels, Belgium                               862.89
# 605   NaN             Gent, Belgium                               754.91
# 606   NaN       Surabaya, Indonesia                               333.14
# 607   NaN    Rostov-na-donu, Russia                               323.03
#
#     Apartment (1 bedroom) Outside of Centre  \
# 0                                    581.79
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2015&itemId=27&itemId=26&itemId=29&itemId=28&itemId=30&itemId=33&itemId=34'
historical_rent8 = pd.read_html(url)

# %%
rent2015 = historical_rent8[2]
rent2015
# Out:
#      Rank                       City Apartment (1 bedroom) in City Centre  \
# 0     NaN            Leuven, Belgium                                    -
# 1     NaN   Saint Petersburg, Russia                               654.94
# 2     NaN             Samara, Russia                                    -
# 3     NaN           Algiers, Algeria                               294.63
# 4     NaN  Eugene, OR, United States                               711.25
# ..    ...                        ...                                  ...
# 537   NaN              Lviv, Ukraine                               245.68
# 538   NaN        Novosibirsk, Russia                               401.45
# 539   NaN          Brussels, Belgium                               840.48
# 540   NaN              Gent, Belgium                               765.03
# 541   NaN     Rostov-na-donu, Russia                               444.41
#
#     Apartment (1 bedroom) Outside of Centre  \
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2014&itemId=27&itemId=26&itemId=29&itemId=28&itemId=30&itemId=33&itemId=34'
historical_rent9 = pd.read_html(url)

# %%
rent2014 = historical_rent9[2]
rent2014
# Out:
#      Rank                                City  \
# 0     NaN            Saint Petersburg, Russia
# 1     NaN                      Samara, Russia
# 2     NaN                    Algiers, Algeria
# 3     NaN  Banja Luka, Bosnia And Herzegovina
# 4     NaN                 Guadalajara, Mexico
# ..    ...                                 ...
# 400   NaN                    Antwerp, Belgium
# 401   NaN                       Lviv, Ukraine
# 402   NaN                 Novosibirsk, Russia
# 403   NaN                   Brussels, Belgium
# 404   NaN                       Gent, Belgium
#
#     Apartment (1 bedroom) in City Centre  \
# 0                                 848.12
# 1                                 572.71
# 2                                      -
# 3                                      -
# 4                                 330.27
# ..                                   ...
# 400                               793.76
# 401                               345.64
# ...

# %%
url = 'https://www.numbeo.com/cost-of-living/historical-prices-by-city?displayCurrency=USD&year=2013&itemId=27&itemId=26&itemId=29&itemId=28&itemId=30&itemId=33&itemId=34'
historical_rent10 = pd.read_html(url)

# %%
rent2013 = historical_rent10[2]
rent2013
# Out:
#      Rank                      City Apartment (1 bedroom) in City Centre  \
# 0     NaN  Saint Petersburg, Russia                              1001.16
# 1     NaN          Algiers, Algeria                               406.09
# 2     NaN           Florence, Italy                               852.21
# 3     NaN              Genoa, Italy                               898.27
# 4     NaN              Milan, Italy                              1281.39
# ..    ...                       ...                                  ...
# 336   NaN             Gent, Belgium                               870.13
# 337   NaN         Sydney, Australia                              2302.87
# 338   NaN            Bologna, Italy                               779.22
# 339   NaN         Alexandria, Egypt                               184.38
# 340   NaN            Quito, Ecuador                               550.00
#
#     Apartment (1 bedroom) Outside of Centre  \
# 0                                    691.22
# ...
